# %% [markdown]
# # Twitter API

# %% [markdown]
# ___API___ é uma interface de progração de aplicativos, que fornece acesso a todos os tweets do site. Além disso é possivel enviar requisições (queries) para os servidores do Twitter para filtrar os tweets baseador em, por exemplo: usuarios, localização, tendencias, termos, hashtags, etc...<br>
# Para isto é necessario uma autenticação.
# * Criando uma conta no Twitter
# * Acessando a pagina de desenvolvedor e vincular
#
# Para fazermos os request a API é necessario adquirir algumas credenciais de identificação:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).

# %% [markdown]
# __Armazenaremos as credenciais e chaves em um arquivo pkl, e através dele forneceremos tais credenciais para acessar a API__

# %%
import pickle #Modulo para serializar dados, "codificar e decodificar"
import os

# %% [markdown]
# ___Executar a celula abaixo apenas uma vez!!!!___

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    #Criando um objeto, Twitter, que armazenará e utilizará todas as credenciais
    Twitter={}
    Twitter['Consumer Key'] = 'vbsRaCIiNRX6dnt5n96Fg30vt'
    Twitter['Consumer Secret'] = 'DaZxTWZpZJUrj8PYKC3DCsqhtN4qoEGbMOygIim8YoRDqE5VjP'
    Twitter['Access Token'] = '1053033058289537025-6MpQJ0QgF6ZeSj8GYpR3fTmBA3jHih'
    Twitter['Access Token Secret'] = '6inkj0hCBb8fWZrcbmkFNa2wjR2Hx43GuqofRpIVl37qq'
    
    with open('secret_twitter_credentials.pkl', 'wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter = pickle.load(open('secret_twitter_credentials.pkl', 'rb'))

# %% [markdown]
# __Agora é necessário intalar o pacote do Twitter para interagir com a API__<br>
# _pip install twitter_

# %% [markdown]
# ## Authorizing an application to access Twitter account data

# %%
#Importando a biblioteca
import twitter

#Criando um objeto da classe twitter para criar outro objeto, este de autenticação
auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

#Passando o a autenticação(objeto autenticação) para um objeto da classe Twitter
twitter_api = twitter.Twitter(auth=auth)

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f473078d450>

# %% [markdown]
# ## Retrieving trends

# %% [markdown]
# O Twitter identifica a localização através do "Yahoo! On Earth ID".<br>
# Para saber topicos de todo o mundo o ID = 1.<br>
# Para verificar o ID de qualquer região: http://woeid.rosselliot.co.nz/

# %%
#Alguns IDs de paises e cidades
WORLD_WOE_ID = 1
BR_WOE_ID = 455819
SP_WOE_ID = 455827
US_WOE_ID = 23424977

# %%
#Solicitando, para a API, os tópicos principais de cada região


#NOTA: É necessario o prefixo "_" ao ID para que a string seja parametrizada para a query.
#Caso contrario o pacote do Twitter adiciona o valor do ID a própria URL como um caso especial.

#O metodo 'trends.place' do objeto (da classe twitter) fornece os 50 tópicos principais de qualquer localização
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
br_trends = twitter_api.trends.place(_id=BR_WOE_ID)
local_trends = twitter_api.trends.place(_id=SP_WOE_ID)

# %% [markdown]
# __A Resposta da API será no formato JSON__<br>
# __JSON__ _é um formato de aqrquivo, semi-estruturado, usado para transferir dados pela web, pode-se fazer um paralelo com os dicionarios e listas do Python_

# %%
#world_trends[:2]
#br_trends[:2]
#local_trends[:2]

# %%
trends = local_trends
print(type(trends)) #Tipo = Objeto da classe twitter com as requisições em json
print(list(trends[0].keys())) #Chaves do arquivo json (semelhante a dicionarios)
#print(trends[0]['trends']) # Printa apenas o primeiro elemento da chave 'trends'
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']

# %% [markdown]
# ## Working with JSON

# %% [markdown]
# Nesta e em varias outras situações é importante saber trabalhar com JSON para entender e analisar dados, principalmente de APIs.

# %%
#Importando modulo do python que trata arquivos em JSON
import json

# %%
#O metodo dumps aparesenta a saida numa forma mais agradável
#O argumento indent=1, faz com que a identação respeite os parenteses, chaves, etc..

print((json.dumps(br_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Wellington Paulista",
#     "url": "http://twitter.com/search?q=%22Wellington+Paulista%22",
#     "promoted_content": null,
#     "query": "%22Wellington+Paulista%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SergioMoroJuizLadrao",
#     "url": "http://twitter.com/search?q=%23SergioMoroJuizLadrao",
#     "promoted_content": null,
#     "query": "%23SergioMoroJuizLadrao",
#     "tweet_volume": 15550
#    },
#    {
#     "name": "#DeixeDeSeguirAPepa",
#     "url": "http://twitter.com/search?q=%23DeixeDeSeguirAPepa",
#     "promoted_content": null,
#     "query": "%23DeixeDeSeguirAPepa",
#     "tweet_volume": 31678
#    },
#    {
#     "name": "Paulo Miranda",
#     "url": "http://twitter.com/search?q=%22Paulo+Miranda%22",
#     "promoted_content": null,
#     "query": "%22Paulo+Miranda%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vitor Carvalho",
#     "url": "http://twitter.com/search?q=%22Vitor+Carvalho%22",
#     "promoted_content": null,
#     "query": "%22Vitor+Carvalho%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OleoNoNordeste",
#     "url": "http://twitter.com/search?q=%23OleoNoNordeste",
#     "promoted_content": null,
#     "query": "%23OleoNoNordeste",
#     "tweet_volume": null
#    },
#    {
#     "name": "#S\u00f3TocaTop",
#     "url": "http://twitter.com/search?q=%23S%C3%B3TocaTop",
#     "promoted_content": null,
#     "query": "%23S%C3%B3TocaTop",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FFPL",
#     "url": "http://twitter.com/search?q=%23FFPL",
#     "promoted_content": null,
#     "query": "%23FFPL",
#     "tweet_volume": null
#    },
#    {
#     "name": "David Braz",
#     "url": "http://twitter.com/search?q=%22David+Braz%22",
#     "promoted_content": null,
#     "query": "%22David+Braz%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Capixaba",
#     "url": "http://twitter.com/search?q=Capixaba",
#     "promoted_content": null,
#     "query": "Capixaba",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bologna",
#     "url": "http://twitter.com/search?q=Bologna",
#     "promoted_content": null,
#     "query": "Bologna",
#     "tweet_volume": 19511
#    },
#    {
#     "name": "Angela Davis",
#     "url": "http://twitter.com/search?q=%22Angela+Davis%22",
#     "promoted_content": null,
#     "query": "%22Angela+Davis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Buffon",
#     "url": "http://twitter.com/search?q=Buffon",
#     "promoted_content": null,
#     "query": "Buffon",
#     "tweet_volume": null
#    },
#    {
#     "name": "Juve",
#     "url": "http://twitter.com/search?q=Juve",
#     "promoted_content": null,
#     "query": "Juve",
#     "tweet_volume": 20500
#    },
#    {
#     "name": "Mallorca",
#     "url": "http://twitter.com/search?q=Mallorca",
#     "promoted_content": null,
#     "query": "Mallorca",
#     "tweet_volume": 33292
#    },
#    {
#     "name": "Thaciano",
#     "url": "http://twitter.com/search?q=Thaciano",
#     "promoted_content": null,
#     "query": "Thaciano",
#     "tweet_volume": null
#    },
#    {
#     "name": "R\u00f4mulo e Andr\u00e9",
#     "url": "http://twitter.com/search?q=%22R%C3%B4mulo+e+Andr%C3%A9%22",
#     "promoted_content": null,
#     "query": "%22R%C3%B4mulo+e+Andr%C3%A9%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "LUCAS VIANA ESTAMOS COM VOC\u00ca",
#     "url": "http://twitter.com/search?q=%22LUCAS+VIANA+ESTAMOS+COM+VOC%C3%8A%22",
#     "promoted_content": null,
#     "query": "%22LUCAS+VIANA+ESTAMOS+COM+VOC%C3%8A%22",
#     "tweet_volume": 12300
#    },
#    {
#     "name": "Phelipe Megiolaro",
#     "url": "http://twitter.com/search?q=%22Phelipe+Megiolaro%22",
#     "promoted_content": null,
#     "query": "%22Phelipe+Megiolaro%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fnatic",
#     "url": "http://twitter.com/search?q=Fnatic",
#     "promoted_content": null,
#     "query": "Fnatic",
#     "tweet_volume": 75833
#    },
#    {
#     "name": "M\u00e1rcio Braga",
#     "url": "http://twitter.com/search?q=%22M%C3%A1rcio+Braga%22",
#     "promoted_content": null,
#     "query": "%22M%C3%A1rcio+Braga%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "O Galhardo",
#     "url": "http://twitter.com/search?q=%22O+Galhardo%22",
#     "promoted_content": null,
#     "query": "%22O+Galhardo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jovic",
#     "url": "http://twitter.com/search?q=Jovic",
#     "promoted_content": null,
#     "query": "Jovic",
#     "tweet_volume": null
#    },
#    {
#     "name": "Moscow",
#     "url": "http://twitter.com/search?q=Moscow",
#     "promoted_content": null,
#     "query": "Moscow",
#     "tweet_volume": 45278
#    },
#    {
#     "name": "Lokah",
#     "url": "http://twitter.com/search?q=Lokah",
#     "promoted_content": null,
#     "query": "Lokah",
#     "tweet_volume": null
#    },
#    {
#     "name": "Courtois",
#     "url": "http://twitter.com/search?q=Courtois",
#     "promoted_content": null,
#     "query": "Courtois",
#     "tweet_volume": null
#    },
#    {
#     "name": "sterling",
#     "url": "http://twitter.com/search?q=sterling",
#     "promoted_content": null,
#     "query": "sterling",
#     "tweet_volume": 26362
#    },
#    {
#     "name": "Reus",
#     "url": "http://twitter.com/search?q=Reus",
#     "promoted_content": null,
#     "query": "Reus",
#     "tweet_volume": null
#    },
#    {
#     "name": "Isco",
#     "url": "http://twitter.com/search?q=Isco",
#     "promoted_content": null,
#     "query": "Isco",
#     "tweet_volume": 10746
#    },
#    {
#     "name": "De Bruyne",
#     "url": "http://twitter.com/search?q=%22De+Bruyne%22",
#     "promoted_content": null,
#     "query": "%22De+Bruyne%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FORxGRE",
#     "url": "http://twitter.com/search?q=%23FORxGRE",
#     "promoted_content": null,
#     "query": "%23FORxGRE",
#     "tweet_volume": null
#    },
#    {
#     "name": "#4YearsWithTWICE",
#     "url": "http://twitter.com/search?q=%234YearsWithTWICE",
#     "promoted_content": null,
#     "query": "%234YearsWithTWICE",
#     "tweet_volume": 229225
#    },
#    {
#     "name": "#GarotosDoNinho",
#     "url": "http://twitter.com/search?q=%23GarotosDoNinho",
#     "promoted_content": null,
#     "query": "%23GarotosDoNinho",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LaLigaFoxPremium",
#     "url": "http://twitter.com/search?q=%23LaLigaFoxPremium",
#     "promoted_content": null,
#     "query": "%23LaLigaFoxPremium",
#     "tweet_volume": null
#    },
#    {
#     "name": "#fcseguefcs",
#     "url": "http://twitter.com/search?q=%23fcseguefcs",
#     "promoted_content": null,
#     "query": "%23fcseguefcs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#goLOUD",
#     "url": "http://twitter.com/search?q=%23goLOUD",
#     "promoted_content": null,
#     "query": "%23goLOUD",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TaMuitoCalorEEu",
#     "url": "http://twitter.com/search?q=%23TaMuitoCalorEEu",
#     "promoted_content": null,
#     "query": "%23TaMuitoCalorEEu",
#     "tweet_volume": null
#    },
#    {
#     "name": "#gameshowproenem",
#     "url": "http://twitter.com/search?q=%23gameshowproenem",
#     "promoted_content": null,
#     "query": "%23gameshowproenem",
#     "tweet_volume": null
#    },
#    {
#     "name": "#fncwin",
#     "url": "http://twitter.com/search?q=%23fncwin",
#     "promoted_content": null,
#     "query": "%23fncwin",
#     "tweet_volume": 14251
#    },
#    {
#     "name": "#SSCWB10ANOS",
#     "url": "http://twitter.com/search?q=%23SSCWB10ANOS",
#     "promoted_content": null,
#     "query": "%23SSCWB10ANOS",
#     "tweet_volume": null
#    },
#    {
#     "name": "#sabadou",
#     "url": "http://twitter.com/search?q=%23sabadou",
#     "promoted_content": null,
#     "query": "%23sabadou",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CaldeiraodoHuck",
#     "url": "http://twitter.com/search?q=%23CaldeiraodoHuck",
#     "promoted_content": null,
#     "query": "%23CaldeiraodoHuck",
#     "tweet_volume": null
#    },
#    {
#     "name": "#4DaysToLoseYouToLoveMe",
#     "url": "http://twitter.com/search?q=%234DaysToLoseYouToLoveMe",
#     "promoted_content": null,
#     "query": "%234DaysToLoseYouToLoveMe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ProgramaDaMaisa",
#     "url": "http://twitter.com/search?q=%23ProgramaDaMaisa",
#     "promoted_content": null,
#     "query": "%23ProgramaDaMaisa",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MeMnoSoTocaTop",
#     "url": "http://twitter.com/search?q=%23MeMnoSoTocaTop",
#     "promoted_content": null,
#     "query": "%23MeMnoSoTocaTop",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GOT7inParis",
#     "url": "http://twitter.com/search?q=%23GOT7inParis",
#     "promoted_content": null,
#     "query": "%23GOT7inParis",
#     "tweet_volume": 154942
#    },
#    {
#     "name": "#Korea_pride_BTS",
#     "url": "http://twitter.com/search?q=%23Korea_pride_BTS",
#     "promoted_content": null,
#     "query": "%23Korea_pride_BTS",
#     "tweet_volume": 561558
#    },
#    {
#     "name": "#ReOrbitLOONA",
#     "url": "http://twitter.com/search?q=%23ReOrbitLOONA",
#     "promoted_content": null,
#     "query": "%23ReOrbitLOONA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HappyChuuDay",
#     "url": "http://twitter.com/search?q=%23HappyChuuDay",
#     "promoted_content": null,
#     "query": "%23HappyChuuDay",
#     "tweet_volume": 31296
#    },
#    {
#     "name": "#ItalianoNoDAZN",
#     "url": "http://twitter.com/search?q=%23ItalianoNoDAZN",
#     "promoted_content": null,
#     "query": "%23ItalianoNoDAZN",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-10-19T21:00:46Z",
#   "created_at": "2019-10-19T20:54:20Z",
#   "locations": [
#    {
#     "name": "Bras\u00edlia",
#     "woeid": 455819
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Intersection of two sets of trends

# %%
#Criando um set com os trends das regiões
#Set são conjuntos desordenados com elementos unicos; possui alguns metodos para cruzar as informações entre 
#dois, ou mais, sets
trends_set = {}
trends_set['world'] = set([trend['name']
                          for trend in world_trends[0]['trends']])

trends_set['br'] = set([trend['name']
                          for trend in br_trends[0]['trends']])

trends_set['local'] = set([trend['name']
                          for trend in local_trends[0]['trends']])

# %%
#Loop para atribuir cada trend a sua respectiva localização e printa-los
for loc in ['world', 'br', 'local']:
    print(('-'*10, loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #لاجديد_بطلنا_يزيد,#لجنه_الانضباط_والاخلاق,#Ulisse,#لبنان_يثور,Mallorca,#JuveBologna,Jovic,#ChileDesperto,Courtois,#MyUnpopularGamingOpinion,#المريخي_واليامي_بالبوليفارد,#ToqueDeQuedaYa,#RenunciaPiñeraCuliao,#headies2019,#19Oct,#UTRPSV,#l6nalbertrivera,#FNCWIN,#SiSePuedeArgentina,Illini,#tusiquevales,#TheWall,#ProphetofCompassion,#NationalPeriodDay,#تصفيات_زد_رصيدك5,#YeniYıla60BinÖğretmen,#StrictlyComeDancing,Badgers,#CelebrityXFactor,#CRYMCI,#4YearsWithTWICE,Buffon,#bensana,#L6NardeCatalunya,#FAQSkeepcalmTV3,#BerniesBack,Lovie Smith,Odriozola,#SerieAxESPN,#ReOrbitLOONA,#BirAileHikayesi,Wisconsin,#الاتحاد_الوحده,#DALS,#ThingsNotToBuyPreOwned,#EkremBaşkanYalnızDeğildir,#Korea_pride_BTS,#تجمع_العاقلين_السعوديين7,#YPGkillsKurds,Abdullah Avcı
# ('----------', 'br')
# #DeixeDeSeguirAPepa,Mallorca,Phelipe Megiolaro,#OleoNoNordeste,Jovic,Courtois,#SóTocaTop,Rômulo e André,#fncwin,Bologna,#SSCWB10ANOS,#ProgramaDaMaisa,Paulo Miranda,sterling,#LaLigaFoxPremium,Angela Davis,#SergioMoroJuizLadrao,Moscow,David Braz,#gameshowproenem,#4DaysToLoseYouToLoveMe,#goLOUD,#TaMuitoCalorEEu,Juve,#MeMnoSoTocaTop,#HappyChuuDay,Wellington Paulista,De Bruyne,#sabadou,#fcseguefcs,O Galhardo,LUCAS VIANA ESTAMOS COM VOCÊ,Fnatic,Lokah,Márcio Braga,#4YearsWithTWICE,Buffon,#FFPL,Reus,Isco,Vitor Carvalho,#ReOrbitLOONA,#Korea_pride_BTS,#GOT7inParis,Thaciano,#FORxGRE,#CaldeiraodoHuck,#ItalianoNoDAZN,#GarotosDoNinho,Capixaba
# ('----------', 'local')
# #DeixeDeSeguirAPepa,País,Mallorca,Toma,Phelipe Megiolaro,#OleoNoNordeste,Jovic,#SóTocaTop,Rômulo e André,#fncwin,Bologna,#SSCWB10ANOS,#ProgramaDaMaisa,Paulo Miranda,#LaLigaFoxPremium,Angela Davis,#SergioMoroJuizLadrao,#gameshowproenem,David Braz,#4DaysToLoseYouToLoveMe,Gilmar Mendes,#goLOUD,#TaMuitoCalorEEu,Juve,#MeMnoSoTocaTop,Wellington Paulista,#sabadou,#fcseguefcs,Desculpa,WhatsApp,O Galhardo,LUCAS VIANA ESTAMOS COM VOCÊ,Waldir,Fnatic,Márcio Braga,Presidente,#4YearsWithTWICE,Buffon,#FFPL,Vitor Carvalho,#ReOrbitLOONA,#BolsonaroEstamosContigo,W. Paulista,#Korea_pride_BTS,#GOT7inParis,Thaciano,#FORxGRE,#CaldeiraodoHuck,#GarotosDoNinho,Capixaba

# %%
#Para analisar a intersecção entre os trends dessas regiões utilizaremos os metodos do objeto set()

#Insersecção entre World e BR
print(('='*10, 'Intersection of world and BR'))
print((trends_set['world'].intersection(trends_set['br'])))

#Intersecção entre BR e SP
print('\n')
print(('='*10, 'Intersection of BR and SP'))
print((trends_set['br'].intersection(trends_set['local'])))
# Out:
# ('==========', 'Intersection of world and BR')
# {'#ReOrbitLOONA', 'Mallorca', '#Korea_pride_BTS', 'Jovic', 'Courtois', '#4YearsWithTWICE', 'Buffon'}
#
#
# ('==========', 'Intersection of BR and SP')
# {'#DeixeDeSeguirAPepa', 'Mallorca', 'Phelipe Megiolaro', 'Jovic', '#OleoNoNordeste', '#SóTocaTop', 'Rômulo e André', '#fncwin', 'Bologna', '#ProgramaDaMaisa', '#SSCWB10ANOS', 'Paulo Miranda', '#LaLigaFoxPremium', 'Angela Davis', '#SergioMoroJuizLadrao', '#gameshowproenem', 'David Braz', '#4DaysToLoseYouToLoveMe', '#goLOUD', '#TaMuitoCalorEEu', 'Juve', '#MeMnoSoTocaTop', 'Wellington Paulista', '#sabadou', '#fcseguefcs', 'O Galhardo', 'LUCAS VIANA ESTAMOS COM VOCÊ', 'Fnatic', 'Márcio Braga', '#4YearsWithTWICE', 'Buffon', '#FFPL', 'Vitor Carvalho', '#ReOrbitLOONA', '#Korea_pride_BTS', '#GOT7inParis', 'Thaciano', '#FORxGRE', '#CaldeiraodoHuck', '#GarotosDoNinho', 'Capixaba'}

# %%
#print((trends_set['local']))

# %% [markdown]
# ## Search for a topic

# %% [markdown]
# Para acessar os tweets sobre um determinado tema:<br>
# __twitter.api.search.tweets(q="topic")__<br><br>
#
# Cada tweet não é apenas uma string de 140 caracteres, mas também um conjunto de varias outras informações relacionadas a cada um deles. Há muitos metadados em cada tweet, que consiste de uma lista de status, que são keys de um dicionario.<br><br>
# __Utilizaremos estes metadados para extrair informações interessantes sobre os tweets__

# %%
#Olhando os tweets relacionados a hastag
topic = '#BolsonaroVagabundo'

#Numero de tweets que iremos coletar
number = 100

#Requisitando a API
#Retorna uma lista ou objeto com os tweets e metadados associados
search_results = twitter_api.search.tweets(q=topic, count=number)


statuses = search_results['statuses']

# %%
len(statuses)
#O resultado, devolvido pela api, esta no formato JSON
print(statuses)
# Out:
# [{'created_at': 'Sat Oct 19 21:02:53 +0000 2019', 'id': 1185662626103209986, 'id_str': '1185662626103209986', 'text': 'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'senadorhumberto', 'name': 'Humberto Costa', 'id': 76049312, 'id_str': '76049312', 'indices': [3, 19]}, {'screen_name': 'jairbolsonaro', 'name': 'Jair M. Bolsonaro', 'id': 128372940, 'id_str': '128372940', 'indices': [45, 59]}], 'urls': []}, 'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 404288195, 'id_str': '404288195', 'name': 'Aldair Miranda 🇧🇷🇻🇪🇨🇺', 'screen_name': 'AldairMiranda1', 'location': '', 'description': 'Analista de Sistemas e Músico Profissional.\nVamos tomar uma que te conto o resto...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 345, 'friends_count': 685, 'listed_count': 0, 'created_at': 'Thu Nov 03 18:15:07 +0000 2011', 'favourites_count': 3368, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4757, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/876079034689626112/Iuw4AZsu_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/876079034689626112/Iuw4AZsu_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Oct 18 20:04:00 +0000 2019', 'id': 1185285419853705216, 'id_str': '1185285419853705216', 'text': 'Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem… https://t.co/0aZ400OfYR', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jairbolsonaro', 'name': 'Jair M. Bolsonaro', 'id': 128372940, 'id_str': '128372940', 'indices': [24, 38]}], 'urls': [{'url': 'https://t.co/0aZ400OfYR', 'expanded_url': 'https://twitter.com/i/web/status/1185285419853705216', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 76049312, 'id_str': '76049312', 'name': 'Humberto Costa', 'screen_name': 'senadorhumberto', 'location': 'Pernambuco', 'description': 'Perfil oficial do Senador Humberto Costa, eleito pelo povo de Pernambuco para batalhar por mais justiça e oportunidades.', 'url': 'https://t.co/pzZRIYjnU7', 'entities': {'url': {'urls': [{'url': 'https://t.co/pzZRIYjnU7', 'expanded_url': 'https://www.senadorhumberto.com.br', 'display_url': 'senadorhumberto.com.br', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected' ...

# %% [markdown]
# ___Frequentemento o twitter devolve resultados duplicados para cada tweet, vamos remove-los___

# %%
all_text=[]
filtered_statuses = []

for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
        
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 68

# %% [markdown]
# _Ou seja, mais da metade dos dados estavam duplicados_

# %%
#Extraindo o texto dos tweets
#Lembrando que 'searcg_results' ainda contem os dados duplicados!!!
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @luh_roma: 😂😂😂😂😂\n\nNa treta eu sou a menina com a manga 🥭 \n\n#BolsonaroVagabundo https://t.co/iITa06WGKw',
#  'RT @christiborati: Mas,  apesar de achar o Deputado Delegado Waldir ser completamente destrambelhado ,  achei que caiu como uma luva o #Bol…',
#  'RT @IvanValente: Mais de vinte anos como deputado, Bolsonaro não fez nada! Como presidente, os resultados positivos que ele entrega ao Bras…',
#  '@folha_poder BRIGUEM E SE MATEM, VAGABUNDOS #BolsonaroVagabundo',
#  'RT @Loro_Maciel: Nova era com a velha política. \n#BolsonaroVagabundo https://t.co/6rz4d2Qp9P',
#  'RT @Adrieli_S: Que injusta essa hashtag #BolsonaroVagabundo, todo mundo sabe que ele trabalhou muito nos 30 anos de congresso dele!\nSegue a…',
#  '#BolsonaroVagabundo\n#BolsonaroVagabundo',
#  'Inútil #BolsonaroVagabundo',
#  '#BolsonaroVagabundo',
#  '#BolsonaroVagabundo',
#  'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…',
#  'RT @luh_roma: 😂😂😂😂\n\nEu estou adorando essa série 😂😂😂😂😂\n\nContinuem kkkk\n\n#BolsonaroVagabundo https://t.co/fGzafQMJBG',
#  'RT @izanildosabino: É bem possível q a gravação q o presidente do PSL tem para implodir Bolsonaro revele quem mandou matar Marielle, a rela…',
#  'boa noite trabalhadores!  #BolsonaroVagabundo',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @camiladelmondes: Nós da esquerda recusamos a atualização da lista de comunistas com o nome da Joice Hasselmman. Favor juntar-se à Tabat…',
#  'RT @camiladelmondes: Atenção, Resistência de Esquerda: não movam uma palha. É pra deixar pegarfogocabaré mesmo #BolsonaroVagabundo',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @the_psofia: TIC TAC...#BolsonaroVagabundo https://t.co/552XX9UkeM',
#  'RT @Capitulinhaa: #BolsonaroVagabundo \nCom as brigas internas do psl, quem é vc na escala vermelho de felicidade ? https://t.co/7lUK1NWs1T',
#  '@carlosjordy @filipebarrost @CarlaZambelli17 @oficialalesilva @bibonunes1 @danielPMERJ 😂😂😂😂😂 #BolsonaroVagabundo',
#  'RT @sidneyrezende: A crise política cravada no centro do poder federal expõe o presidente @jairbolsonaro, sua família política e o núcleo m…',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'Acho que podiam fazer um reality show com essa galera do PSL, para inovar deixa todos eles levarem suas armas. Afin… https://t.co/EiVFbfGy1j',
#  'RT @MussumAlive: FALAE  #BolsonaroVagabundo',
#  '#BolsonaroVagabundo https://t.co/FbjnQGVYtp',
#  '@zehdeabreu @VEJA #BolsonaroVagabundo',
#  '#BolsonaroVagabundo https://t.co/OwFEMGY8OH',
#  '@FinancialTimes #BolsonaroVagabundo #LulaLivre  Valdir chama presidente @jairbolsonaro bolsode #BolsonaroVagabundo… https://t.co/u4xePlHs86',
#  'RT @Vavomoreira: Entro no Twitter e dou de cara com a hashtag #BolsonaroVagabundo bombando. Como eu amo essa rede social aaa https://t.co/w…',
#  '@VEJA #BolsonaroVagabundo',
#  '#BolsonaroVagabundo https://t.co/HJ4fg5Ln30',
#  "👩 Jennifer Aniston joins Instagram with help from some 'Friends' 🤳🏻 Leitura e tradução de texto em inglês →… https://t.co/rTtfC7SKIY",
#  '@waltermirinfo @PSL_Nacional Idiota fanático, cego e perturbado. #ImpeachmentdoBolsonaroURGENTE #BolsonaroVagabundo',
#  'RT @luh_roma: 😂😂😂😂😂\n\nNa treta eu sou a menina com a manga 🥭 \n\n#BolsonaroVagabundo https://t.co/iITa06WGKw',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @luh_roma: 😂😂😂😂\n\nEu estou adorando essa série 😂😂😂😂😂\n\nContinuem kkkk\n\n#BolsonaroVagabundo https://t.co/fGzafQMJBG',
#  'RT @K_13PT: #BolsonaroVagabundo 🖕 https://t.co/NqkDnN9HHt',
#  '#BolsonaroVagabundo Boa Noite KKK',
#  '#BolsonaroVagabundo https://t.co/i3KLjT3fea',
#  '@folha #BolsonaroVagabundo #Bolsolao',
#  '@sorr_el BURRRRRRRROOOO BEM FEITO BOLSOMINION TEM  QUE TOMA NO CU SE FERROU PALHAÇO HAHAHAHS #BolsonaroVagabundo',
#  'RT @TiaBiba49: Paolla Carossella chama delegado Waldir de imundo, já o delegado chama #BolsonaroVagabundo \n\nNunca vi um governo tão ralé, t…',
#  '@jairbolsonaro @AbrahamWeint #BolsonaroVagabundo https://t.co/incezBx5MG',
#  '#PSLtraidor já estão xingando o mito de VA-GA-BUN-DO #BolsonaroVagabundo, HÁ MUITA VAGA, ABUNDA',
#  '@UOLNoticias @danailamarc #BolsonaroVagabundo',
#  'RT @Ribeiro_T: VA GA BUN DO #BolsonaroVagabundo https://t.co/qftFlbFsSE',
#  'Atenção, Resistência de Esquerda: não movam uma palha. É pra deixar pegarfogocabaré mesmo #BolsonaroVagabundo',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…',
#  'RT @senadorhumberto: A sabedoria popular já diz que quem se junta com porco, farelo come. 🐷 #BolsonaroVagabundo https://t.co/zfpbgcZ7IL',
#  '#BolsonaroVagabundo',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…',
#  'voce acha o governo do bolsonaro como até agora? #BolsonaroVagabundo \n#Bolsolao',
#  'RT @luh_roma: 😂😂😂😂\n\nEu estou adorando essa série 😂😂😂😂😂\n\nContinuem kkkk\n\n#BolsonaroVagabundo https://t.co/fGzafQMJBG',
#  '#BolsonaroVagabundo https://t.co/eY9oI5a2Zi',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  '@jairbolsonaro #BolsonaroVagabundo https://t.co/4YS3Ch4Qtu',
#  'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…',
#  '@Amarulacarvalho #BolsonaroVagabundo',
#  'RT @joomikhail: #BolsonaroVagabundo\nEi ...Presidente !! Acorda !! \nDesce do palenque e GOVERNA !!! https://t.co/D1zoDSnHAE',
#  'RT @DayseLivre: #BolsonaroVagabundo é a tag de hoje,  vamos usar e abusar. https://t.co/9fWZPbk1hN',
#  'RT @luh_roma: 😂😂😂😂\n\nEu estou adorando essa série 😂😂😂😂😂\n\nContinuem kkkk\n\n#BolsonaroVagabundo https://t.co/fGzafQMJBG',
#  'RT @joomikhail: #BolsonaroVagabundo\nE o Dudu hein ?? \nNem Embaixada \nNem liderança do partido ..\nMas..... Nem tudo esta perdido.. https://t…',
#  '@jairbolsonaro @Astro_Pontes @mctic @MinEconomia @CarlosBolsonaro #BolsonaroVagabundo https://t.co/tEB9p7eA5a',
#  '#BolsonaroVagabundo melhor tag de hoje https://t.co/IN9acnyBnx',
#  'RT @Adrieli_S: Que injusta essa hashtag #BolsonaroVagabundo, todo mundo sabe que ele trabalhou muito nos 30 anos de congresso dele!\nSegue a…',
#  'RT @Adrieli_S: Que injusta essa hashtag #BolsonaroVagabundo, todo mundo sabe que ele trabalhou muito nos 30 anos de congresso dele!\nSegue a…',
#  'RT @marcelomatuska: Pega fogo Laranjal!!!\n#BolsonaroVagabundo https://t.co/gFzi0oFmVA',
#  'RT @Jacck13: E o vagabundo era o Mito do gado 😂😂😂\n#BolsonaroVagabundo https://t.co/TIsglrDofh',
#  'Cai logo #BolsonaroVagabundo que eu sofro de ansiedade! https://t.co/II33mUiKAz',
#  '. #BolsonaroVagabundo',
#  'RT @luh_roma: Eita cabaré kkkkkk\n\nNem George Lucas faria um filme à altura 😂😂😂\n\n#QueimaQuengaral #BolsonaroVagabundo #BolsonaroEnvergonhaOB…',
#  'RT @luh_roma: Iiiiiihhhhhhhhh..... Silas Maracutaia entrou pro fight !\n\nSexta do descarrego !? 😂😂😂😂\n\n#BolsonaroVagabundo https://t.co/r7Ayx…',
#  'RT @Jacck13: E o vagabundo era o Mito do gado 😂😂😂\n#BolsonaroVagabundo https://t.co/TIsglrDofh',
#  '#BolsonaroVagabundo, dizem que é miliciano também, será?',
#  'RT @falandoverdes2: E não é que o petróleo não era Venezuelano:\nhttps://t.co/TleBxccejn\n#BolsonaroVagabundo',
#  '#BolsonaroVagabundo https://t.co/Pz9PM96bXZ',
#  'RT @IvanValente: Mais de vinte anos como deputado, Bolsonaro não fez nada! Como presidente, os resultados positivos que ele entrega ao Bras…',
#  'RT @senadorhumberto: A sabedoria popular já diz que quem se junta com porco, farelo come. 🐷 #BolsonaroVagabundo https://t.co/zfpbgcZ7IL',
#  'RT @hospicio_brasil: Ele xinga, pragueja, esperneia, finge que trabalha, mas nunca produziu nada de relevante para o país. Sequer um alfine…',
#  '#BolsonaroVagabundo absurdo  ter um Presidente sem respeito dentro e fora do Brasil.',
#  'A costa Nordestina destruída por piche e o @jairbolsonaro engalfinhado em disputas políticas. O Brasil é um hospício. #BolsonaroVagabundo',
#  'Adoro uma tag assim #BolsonaroVagabundo',
#  'RT @IvanValente: Mais de vinte anos como deputado, Bolsonaro não fez nada! Como presidente, os resultados positivos que ele entrega ao Bras…',
#  'RT @senadorhumberto: Esse é o espantalho que @JairBolsonaro escolheu para ministro da Educação. É uma vergonha por dia. Assistam e podem vo…',
#  '#BolsonaroVagabundo #Bolsolão gente ta impossível acompanhar os fatos, me gritem aqui qdo chegar o impitima',
#  'RT @Fabio_Gou: Ei, vc q não gosta de política e está aqui só para defender o país...\n\nNão te parece estranho que o herói patriota seja o Ca…',
#  'RT @lindberghfarias: PSL suspende 5 dep. ligados a Bolsonaro: Carla Zambelli (SP), Bibo Nunes (RS), Ale Silva (MG), Felipe Barros (PR) e Ca…',
#  'E agora @TSEjusbr com a afirmação (grave) da Joiça 👇sobre a rede criminosa da Família Bolsonaro, haverá ou não puni… https://t.co/FwVvkQdfmE']

# %%
#Outra forma de exibir estes dados é utilizando os metodos para lidar com arquivos JSON
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri Oct 18 21:22:20 +0000 2019",
#  "id": 1185305132080226304,
#  "id_str": "1185305132080226304",
#  "text": "RT @luh_roma: \ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\n\nNa treta eu sou a menina com a manga \ud83e\udd6d \n\n#BolsonaroVagabundo https://t.co/iITa06WGKw",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "BolsonaroVagabundo",
#     "indices": [
#      62,
#      81
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "luh_roma",
#     "name": "\ud83c\udf3b \u00a3uh \ud83c\udf3b\ud83d\udea9",
#     "id": 1103929793689542659,
#     "id_str": "1103929793689542659",
#     "indices": [
#      3,
#      12
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1185241147934986240,
#     "id_str": "1185241147934986240",
#     "indices": [
#      82,
#      105
#     ],
#     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#     "url": "https://t.co/iITa06WGKw",
#     "display_url": "pic.twitter.com/iITa06WGKw",
#     "expanded_url": "https://twitter.com/luh_roma/status/1185241207095603201/video/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 680,
#       "h": 680,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1185241207095603201,
#     "source_status_id_str": "1185241207095603201",
#     "source_user_id": 1103929793689542659,
#     "source_user_id_str": "1103929793689542659"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1185241147934986240,
#     "id_str": "1185241147934986240",
#     "indices": [
#      82,
#      105
#     ],
#     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#     "url": "https://t.co/iITa06WGKw",
#     "display_url": "pic.twitter.com/iITa06WGKw",
#     "expanded_url": "https://twitter.com/luh_roma/status/1185241207095603201/video/1",
#     "type": "video",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 680,
#       "h": 680,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1185241207095603201,
#     "source_status_id_str": "1185241207095603201",
#     "source_user_id": 1103929793689542659,
#     "source_user_id_str": "1103929793689542659",
#     "video_info": {
#      "aspect_ratio": [
#       1,
#       1
#      ],
#      "duration_millis": 9933,
#      "variants": [
#       {
#        "bitrate": 432000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/320x320/tR3r5gSKaVLpBck2.mp4?tag=10"
#       },
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/pl/KEolrVsysILlaxPL.m3u8?tag=10"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/480x480/fWuLlwZT3L0PTXUN.mp4?tag=10"
#       },
#       {
#        "bitrate": 1280000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/720x720/Jrpi-D-EA2acHs-q.mp4?tag=10"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "monetizable": false,
#      "source_user": {
#       "id": 1103929793689542659,
#       "id_str": "1103929793689542659",
#       "name": "\ud83c\udf3b \u00a3uh \ud83c\udf3b\ud83d\udea9",
#       "screen_name": "luh_roma",
#       "location": "Italia",
#       "description": "\u201c ... porque sou linda ,porque sou meiga e porque sou uma menina com uma flor\u201d \ud83c\udf3b( Vinicius de Moraes ) #EsquerdistaSeguemEsquerdistas\ud83d\udc4a\ud83c\udffb",
#       "url": null,
#       "entities": {
#        "description": {
#         "urls": []
#        }
#       },
#       "protected": false,
#       "followers_count": 18256,
#       "friends_count": 18485,
#       "listed_count": 11,
#       "created_at": "Fri Mar 08 08:05:47 +0000 2019",
#       "favourites_count": 28460,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 13069,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "000000",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1184355105145012226/v9Swb0uy_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1184355105145012226/v9Swb0uy_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1103929793689542659/1570542307",
#       "profile_link_color": "E81C4F",
#       "profile_sidebar_border_color": "000000",
#       "profile_sidebar_fill_color": "000000",
#       "profile_text_color": "000000",
#       "profile_use_background_image": false,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "pt",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1001886133251387393,
#   "id_str": "1001886133251387393",
#   "name": "franzinha\ud83d\udc20",
#   "screen_name": "_eufranzinha",
#   "location": "Brasil",
#   "description": "\ud83d\udcccDEUS,MEU TUDO!!!\ud83d\udccc\n#bonderenault #teampeixinho #Mariel #flacelo #PaulaAmorim",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 869,
#   "friends_count": 1117,
#   "listed_count": 0,
#   "created_at": "Wed May 30 18:00:43 +0000 2018",
#   "favourites_count": 32122,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 18131,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1181298887438426112/GsjOVnqV_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1181298887438426112/GsjOVnqV_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1001886133251387393/1563640508",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Fri Oct 18 17:08:19 +0000 2019",
#   "id": 1185241207095603201,
#   "id_str": "1185241207095603201",
#   "text": "\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\n\nNa treta eu sou a menina com a manga \ud83e\udd6d \n\n#BolsonaroVagabundo https://t.co/iITa06WGKw",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "BolsonaroVagabundo",
#      "indices": [
#       48,
#       67
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1185241147934986240,
#      "id_str": "1185241147934986240",
#      "indices": [
#       68,
#       91
#      ],
#      "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#      "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#      "url": "https://t.co/iITa06WGKw",
#      "display_url": "pic.twitter.com/iITa06WGKw",
#      "expanded_url": "https://twitter.com/luh_roma/status/1185241207095603201/video/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 680,
#        "h": 680,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1185241147934986240,
#      "id_str": "1185241147934986240",
#      "indices": [
#       68,
#       91
#      ],
#      "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#      "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1185241147934986240/pu/img/EJ-CXSBBwUSsfyQP.jpg",
#      "url": "https://t.co/iITa06WGKw",
#      "display_url": "pic.twitter.com/iITa06WGKw",
#      "expanded_url": "https://twitter.com/luh_roma/status/1185241207095603201/video/1",
#      "type": "video",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 680,
#        "h": 680,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "video_info": {
#       "aspect_ratio": [
#        1,
#        1
#       ],
#       "duration_millis": 9933,
#       "variants": [
#        {
#         "bitrate": 432000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/320x320/tR3r5gSKaVLpBck2.mp4?tag=10"
#        },
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/pl/KEolrVsysILlaxPL.m3u8?tag=10"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/480x480/fWuLlwZT3L0PTXUN.mp4?tag=10"
#        },
#        {
#         "bitrate": 1280000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/ext_tw_video/1185241147934986240/pu/vid/720x720/Jrpi-D-EA2acHs-q.mp4?tag=10"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "monetizable": false
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "pt",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1103929793689542659,
#    "id_str": "1103929793689542659",
#    "name": "\ud83c\udf3b \u00a3uh \ud83c\udf3b\ud83d\udea9",
#    "screen_name": "luh_roma",
#    "location": "Italia",
#    "description": "\u201c ... porque sou linda ,porque sou meiga e porque sou uma menina com uma flor\u201d \ud83c\udf3b( Vinicius de Moraes ) #EsquerdistaSeguemEsquerdistas\ud83d\udc4a\ud83c\udffb",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 18256,
#    "friends_count": 18485,
#    "listed_count": 11,
#    "created_at": "Fri Mar 08 08:05:47 +0000 2019",
#    "favourites_count": 28460,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 13069,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1184355105145012226/v9Swb0uy_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1184355105145012226/v9Swb0uy_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1103929793689542659/1570542307",
#    "profile_link_color": "E81C4F",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 97,
#   "favorite_count": 428,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "pt"
#  },
#  "is_quote_status": false,
#  "retweet_count": 97,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "pt"
# }

# %% [markdown]
# ## Extract text, screen names, and hashtags from tweets

# %%
status_texts = [status['text'] for status in statuses]

screen_names = [user_mention['screen_name'] for status in statuses
                                               for user_mention in status['entities']['user_mentions']]

hashtags = [hashtag['text'] for status in statuses
                               for hashtag in status['entities']['hashtags']]

#Criando uma bag-of-words com as palavras dos tweets
words = [w for t in status_texts
            for w in t.split()]

# %%
#Utilizando o metodo do pacote JSON para analisar os primeiros 5 elementos das listas criadas
print(json.dumps(status_texts[:5], indent=1))
print(json.dumps(screen_names[:5], indent=1))
print(json.dumps(hashtags[:5], indent=1))
print(json.dumps(words[:5], indent=1))
# Out:
# [
#  "RT @luh_roma: \ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\n\nNa treta eu sou a menina com a manga \ud83e\udd6d \n\n#BolsonaroVagabundo https://t.co/iITa06WGKw",
#  "RT @christiborati: Mas,  apesar de achar o Deputado Delegado Waldir ser completamente destrambelhado ,  achei que caiu como uma luva o #Bol\u2026",
#  "RT @IvanValente: Mais de vinte anos como deputado, Bolsonaro n\u00e3o fez nada! Como presidente, os resultados positivos que ele entrega ao Bras\u2026",
#  "@folha_poder BRIGUEM E SE MATEM, VAGABUNDOS #BolsonaroVagabundo",
#  "RT @Loro_Maciel: Nova era com a velha pol\u00edtica. \n#BolsonaroVagabundo https://t.co/6rz4d2Qp9P"
# ]
# [
#  "luh_roma",
#  "christiborati",
#  "IvanValente",
#  "folha_poder",
#  "Loro_Maciel"
# ]
# [
#  "BolsonaroVagabundo",
#  "BolsonaroVagabundo",
#  "BolsonaroVagabundo",
#  "BolsonaroVagabundo",
#  "BolsonaroVagabundo"
# ]
# [
#  "RT",
#  "@luh_roma:",
#  "\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02",
#  "Na",
#  "treta"
# ]

# %% [markdown]
# # Create Frequency Distributions

# %% [markdown]
# _Utilizaremos o pacote padrão __collections__ que contem a classe __Counter__ que torna fácil criar distribuições de frequencias._

# %% [markdown]
# __Fazendo desta forma o output seria muito difícil de se ler devido a sintaxe, por tanto usaremos algumas formas de formatação de strings para melhorar a leitura do output.__<br>

# %% [markdown]
# <center>print("{:20} | {:>6}".format(k,v))</center>

# %% [markdown]
# Para cada string printada, teremos:<br>
# __{:20}__ Irá moldar a string em 20 espaços <br>
# __{:^20}__ Irá centralizar a string no meio de 20 espaços<br>
# __{:>20}__ Irá alinhas à direita de 20 espaços

# %% [markdown]
# Para mais: https://pyformat.info/

# %%
#A classe counter retorna uma lista e conta quantas vezes cada item se repete
from collections import Counter

# %%
#O metodo "most_common()" retorna as contagens ordenadas
for item in [words, screen_names, hashtags]:
    #'c' é um objeto da classe Counter
    c = Counter(item)
    print(c.most_common()[:10])
    print()
# Out:
# [('#BolsonaroVagabundo', 53), ('RT', 30), ('o', 20), ('de', 16), ('a', 11), ('que', 11), ('e', 11), ('do', 10), ('com', 7), ('não', 7)]
#
# [('jairbolsonaro', 7), ('luh_roma', 4), ('senadorhumberto', 2), ('camiladelmondes', 2), ('VEJA', 2), ('joomikhail', 2), ('christiborati', 1), ('IvanValente', 1), ('folha_poder', 1), ('Loro_Maciel', 1)]
#
# [('BolsonaroVagabundo', 58), ('Bolsolao', 2), ('LulaLivre', 1), ('ImpeachmentdoBolsonaroURGENTE', 1), ('PSLtraidor', 1), ('QueimaQuengaral', 1), ('Bolsolão', 1)]

# %% [markdown]
# _Este output, uma lista de tuplas, é dificil de ler, devido a sintaxe, vamos melhorar isso:_

# %%
#função para deixar o output mais legível
#Imprime uma "tabela" com as informações desejadas
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), ('Screen Name', screen_names), ('Hashtags', hashtags)):
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# #BolsonaroVagabundo  |     53
# RT                   |     30
# o                    |     20
# de                   |     16
# a                    |     11
# que                  |     11
# e                    |     11
# do                   |     10
# com                  |      7
# não                  |      7
#
#     Screen Name      | Count
# ****************************************
# jairbolsonaro        |      7
# luh_roma             |      4
# senadorhumberto      |      2
# camiladelmondes      |      2
# VEJA                 |      2
# joomikhail           |      2
# christiborati        |      1
# IvanValente          |      1
# folha_poder          |      1
# Loro_Maciel          |      1
#
#       Hashtags       | Count
# ****************************************
# BolsonaroVagabundo   |     58
# Bolsolao             |      2
# LulaLivre            |      1
# ImpeachmentdoBolsonaroURGENTE |      1
# PSLtraidor           |      1
# QueimaQuengaral      |      1
# Bolsolão             |      1

# %% [markdown]
# ## Finding the most popular retweets

# %%
#Analisaremos através do numero de retweets
#Primeiro armazenamos uma lista de tuplas, garantindo que o contador do tweet (nº de vezes que ele foi retuitado)
#seja o primeiro elemento da tupla

#LIST COMPREHENSIONS
retweets = [
            #Armazenando uma tupla com esse valores...
            (status['retweet_count'],
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n", "\\"))
    
            #Para cada status...
            for status in statuses
                #Desde que...
                if 'retweeted_status' in status
            ]

# %%
#len(retweets)

# %% [markdown]
# __Agora contruiremos outra função prettyprint para imprimir o tweet inteiro, ou seja, tweet com retweet__<br>
# _Também dividir o tweet em 3 linhas se for necessario_

# %%
row_template = "{:^7} | {:^15} | {:50}"

def prettyprint_tweets_2(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*80)
    for count, screen_names, text in list_of_tuples:
        #Dividindo o tweet 3 linhas, com 50 caracteres cada para ter alguma margem
        #Se o tweet for muito pequeno isto nao será preciso
        #Se for maior será divido em outras linhas
        print(row_template.format(count, screen_names, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))
        print('-'*80)

# %%
#Printando - de forma legível - os 5 tweets mais populares
#A função "sorted" retorna os elementos de uma lista, ordenado

prettyprint_tweets_2(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ********************************************************************************
#   457   |    Adrieli_S    | RT @Adrieli_S: Que injusta essa hashtag #Bolsonaro
#         |                 | Vagabundo, todo mundo sabe que ele trabalhou muito
#         |                 |  nos 30 anos de congresso dele!\Segue a…
# --------------------------------------------------------------------------------
#   393   | hospicio_brasil | RT @hospicio_brasil: Ele xinga, pragueja, espernei
#         |                 | a, finge que trabalha, mas nunca produziu nada de
#         |                 | relevante para o país. Sequer um alfine…
# --------------------------------------------------------------------------------
#   374   | izanildosabino  | RT @izanildosabino: É bem possível q a gravação q
#         |                 | o presidente do PSL tem para implodir Bolsonaro re
#         |                 | vele quem mandou matar Marielle, a rela…
# --------------------------------------------------------------------------------
#   324   |     Jacck13     | RT @Jacck13: E o vagabundo era o Mito do gado 😂😂😂\
#         |                 | #BolsonaroVagabundo https://t.co/TIsglrDofh
# --------------------------------------------------------------------------------
#   184   | senadorhumberto | RT @senadorhumberto: A sabedoria popular já diz qu
#         |                 | e quem se junta com porco, farelo come. 🐷 #Bolsona
#         |                 | roVagabundo https://t.co/zfpbgcZ7IL
# --------------------------------------------------------------------------------
#   145   |   IvanValente   | RT @IvanValente: Mais de vinte anos como deputado,
#         |                 |  Bolsonaro não fez nada! Como presidente, os resul
#         |                 | tados positivos que ele entrega ao Bras…
# --------------------------------------------------------------------------------
#   126   |   joomikhail    | RT @joomikhail: #BolsonaroVagabundo\Ei ...Presiden
#         |                 | te !! Acorda !! \Desce do palenque e GOVERNA !!! h
#         |                 | ttps://t.co/D1zoDSnHAE
# --------------------------------------------------------------------------------
#   123   |    luh_roma     | RT @luh_roma: 😂😂😂😂\\Eu estou adorando essa série 😂
#         |                 | 😂😂😂😂\\Continuem kkkk\\#BolsonaroVagabundo https://
#         |                 | t.co/fGzafQMJBG
# --------------------------------------------------------------------------------
#   112   |    luh_roma     | RT @luh_roma: Eita cabaré kkkkkk\\Nem George Lucas
#         |                 |  faria um filme à altura 😂😂😂\\#QueimaQuengaral #Bo
#         |                 | lsonaroVagabundo #BolsonaroEnvergonhaOB…
# --------------------------------------------------------------------------------
#   104   | lindberghfarias | RT @lindberghfarias: PSL suspende 5 dep. ligados a
#         |                 |  Bolsonaro: Carla Zambelli (SP), Bibo Nunes (RS),
#         |                 | Ale Silva (MG), Felipe Barros (PR) e Ca…
# --------------------------------------------------------------------------------
