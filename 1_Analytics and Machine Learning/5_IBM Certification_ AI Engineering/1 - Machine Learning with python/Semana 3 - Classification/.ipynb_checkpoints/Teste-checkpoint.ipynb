# %%
import pandas as pd

# %%
df = pd.read_excel('Saúde Emocional no Ambiente de Trabalho (respostas).xlsx')
df = df.drop('Carimbo de data/hora', axis=1)
df.head()
# Out:
#   Qual o seu gênero? Qual a sua faixa etária? Qual o seu nível hierárquico?  \
# 0          Masculino             30 a 38 anos                      Analista
# 1          Masculino             30 a 38 anos                       Gerente
# 2          Masculino             30 a 38 anos                       Gerente
# 3           Feminino             39 a 50 anos                      Analista
# 4           Feminino             30 a 38 anos                        Outros
#
#   Você excede sua jornada de trabalho?  \
# 0                       Sim, as vezes.
# 1            Sim, com muita frequência
# 2            Sim, com muita frequência
# 3            Sim, com muita frequência
# 4            Sim, com muita frequência
#
#   Como você avalia o seu ambiente de trabalho?   \
# 0                                      Amigável
# 1                                    Desafiador
# 2                                      Amigável
# 3                                  Colaborativo
# ...

# %%
df.rename(columns={'Qual o seu gênero?':'genero', 'Qual a sua faixa etária?':'faixa etaria',
                   'Qual o seu nível hierárquico?':'cargo',
                  'Você excede sua jornada de trabalho?':'excede_jornada',}, inplace=True)

# %%
df.head()
# Out:
#       genero  faixa etaria     cargo             excede_jornada  \
# 0  Masculino  30 a 38 anos  Analista             Sim, as vezes.
# 1  Masculino  30 a 38 anos   Gerente  Sim, com muita frequência
# 2  Masculino  30 a 38 anos   Gerente  Sim, com muita frequência
# 3   Feminino  39 a 50 anos  Analista  Sim, com muita frequência
# 4   Feminino  30 a 38 anos    Outros  Sim, com muita frequência
#
#   Como você avalia o seu ambiente de trabalho?   \
# 0                                      Amigável
# 1                                    Desafiador
# 2                                      Amigável
# 3                                  Colaborativo
# 4                                   Competitivo
#
#   Você passou por alguma situação traumática dentro do ambiente corporativo, se sim, com que frequencia?   \
# 0                                       Quase sempre
# 1                                              Nunca
# 2                                      Algumas vezes
# ...
